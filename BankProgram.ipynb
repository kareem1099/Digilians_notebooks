# %%
x=int(input("enter your pyramid depth"))
for i in range(1,x,2):
    print(" "*(((x-1)-i)//2) + "*"*i )
# Out:
#               *
#              ***
#             *****
#            *******
#           *********
#          ***********
#         *************
#        ***************
#       *****************
#      *******************
#     *********************
#    ***********************
#   *************************
#  ***************************
# *****************************

# %%
bank_database={
    "ahmed":{
        "pass":"12345",
        "balance":5000,
        "history":[]
    },
    "sayed":{
        "pass":"12345",
        "balance":10000,
        "history":[]
    },
    "ibrahim":{
        "pass":"12345",
        "balance":7000,
        "history":[]
    },
    "loay":{
        "pass":"12345",
        "balance":8000,
        "history":[]
    },
    "sama":{
        "pass":"12345",
        "balance":9000,
        "history":[]
    },
    "tasneem":{
        "pass":"12345",
        "balance":6000,
        "history":[]
    },
    "roqia":{
        "pass":"12345",
        "balance":4000,
        "history":[]
    },
    "sally":{
        "pass":"12345",
        "balance":3000,
        "history":[]
    },
}

def homepage():

    print("*"*20)

    print("service menu")

    print(""" 
            chosse your service : 
            1 for Balance check
            2 for withdrawl
            3 for deposit
            q for exit

            input 1 or 2 or 3 or q only! 

        """)
    x=input()
    return x


print("Welcome to our bank")


print("Login page")

while True:
 print("Login page")
 print("enter your username")
 user_name=input()
 if user_name=="q":
     break
 keys=bank_database.keys()
 if user_name in keys:
    print("enter your password")
    passw=input()
    if passw==bank_database[user_name]['pass']:
    
        while True:
   
            x=homepage()


            if x in "123q":
                if x=="1":
                    print(f"Your balance is {bank_database[user_name]['balance']}")
                if x=="2":
                    print("enter the amount")
                    y=int(input())
                    bank_database[user_name]['balance']-=y
                    print(f"withdrwal done Your balance is {bank_database[user_name]['balance']}")
                if x=="3":
                    print("enter the amount")
                    y=int(input())
                    bank_database[user_name]['balance']+=y
                    print(f"deposit done if you want to check the bance click 1, wanna exit click q")
                    z=input()

                    if z=="1":
                        print(f"Your balance is {bank_database[user_name]['balance']}")
                    
                    if z=="q":
                        break
                if x=="q":
                    print(f"thanks for chossing us ")
    
                    break
    else:
        print("enter valid password")            
 elif user_name=="q":
     break
 else:
    print("username is not valid ente valid one or q to quit instead")
# Out:
# Your balance is 4500
# ********************
# service menu
#
#             chosse your service :
#             1 for Balance check
#             2 for withdrawl
#             3 for deposit
#             q for exit
#
#             input 1 or 2 or 3 or q only!
#
#
# enter the amount
# deposit done if you want to check the bance click 1, wanna exit click q
# Your balance is 5000
# ********************
# service menu
#
#             chosse your service :
#             1 for Balance check
#             2 for withdrawl
#             3 for deposit
#             q for exit
#
#             input 1 or 2 or 3 or q only!
#
#
# thanks for chossing us
# Login page
# enter your username
